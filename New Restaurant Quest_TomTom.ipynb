# %% [markdown]
# # Where to Open a Chinese Restaurant in Amsterdam?<a id='top'></a>
#
# ### Table of contents
#
# 1. [Background](#0)
# 2. [The Challenge](#1)
#
#
# <hr style="border: 1px solid orange;">

# %% [markdown]
# <a id="0"></a>
# # Background
#
# This is the virtual challenge I choose to complete an online Data Science course. And I have so much fun tackling the challenge using TomTom Maps API, I would like to share the project with others.
#
# <a id="1"></a>
# # The Challenge
#
# Linda has a dream to open a Chinese restaurant to share the joy of great food with others. Now, everything is ready, she chooses Amsterdam to be the place where her dream takes off. Not only because Amsterdam is one of the most populous and visited cities in Europe but also because the diverse culture the city embraces.
#
# ## 1.1. The Approach
#
# The big question is, where to open a Chinese restaurant in Amsterdam. We need to collect data from at least two sources to narrow down the selection:
#
# * Demographic data (for instance: population density per area in Amsterdam)
# * Data of the surroundings (for instance: density of similar restaurants nearby)
#
# Since you are here to read about fantastic things you can do with TomTom Maps API, I will be much more focused on the second part: Data of the surroundings.
#
# If you are interested in the complete story, please read: https://nbviewer.jupyter.org/github/xding78/Coursera_Capstone/blob/master/Final%20Assignment%20-%20Week%202.ipynb

# %% [markdown]
# ## 1.3. Business Questions<a id="13"></a>
#
# To find the ideal location for the restaurant, we must first seek answers to a few questions.
#
# ### Question 1: How many restaurants already exist?
#
# If this new restaurant would be the only one in a neighborhood, there will be more profit for Linda. So, the number of existing  restaurants in the neighborhood must be taken into consideration.
# Again, this question can be answered, hopefully, by using Foursquare API.
#
# ### Question 2: How popular will Chinese food be in the neighborhood?
#
# For Linda, it's important to serve traditional Chinese food the way she knows. Even though Chinese food is widely loved, it makes sense to double check how existing Chinese restaurants (or Asian restaurants) are perceived.
# This question can be answered, hopefully, by using Foursquare API.
#
# ### Question 3: Who are the target customers and where do they live?
#
# It is going to be a small restaurant (5 to 7 tables) due to the limited investment. The primary income would be takeout and orders made online.
# From past experience, Linda knows that people who live alone are more likely to buy takeout or use online food ordering apps such as Uber Eats. They are the ideal target customers for her new restaurant. So, we will look for an area with a relatively high density of one-person household.
# We need demographic information to answer this question.
#
# <br>
# <hr style="border: 1px solid orange;">

# %% [markdown]
# # 2. Data Requirements<a id="2"></a>
# [Back to top](#top)
#
# We have the big question, where to open a Chinese restaurant in Amsterdam. Now, we need to collect data that can help us answer the questions. We need to collect data from at least two sources:
#
# * Data of the surroundings (density of similar restaurants nearby)
# * Demographic data (per area in Amsterdam)

# %% [markdown]
# ## 2.1. Data of Surroundings<a id="21"></a>
# [Back to top](#top)
#
# #### TomTom Search API:
# Find all point of interest (POI) per categories around a certain location.
#
# * [**Search API documentations**](https://developer.tomtom.com/search-api/search-api-documentation)
# * [**Search API Explorer**](https://developer.tomtom.com/content/search-api-explorer#/Search/get_search__versionNumber__poiSearch__query___ext_)

# %% [markdown]
# ## 2.2 Demographic Data<a id="22"></a>
# [Back to top](#top)
#
# ### Demographic features that are crucial to learn for this project:
#
# * **Total Households**: Number of households in a neighborhood.
#   * High number of total households guarantees a solid base of potential customers.
# * **Population density**: A more densely populated area means more customers for a restaurant. The unit of population density is **number of people per square kilometer**.
#   * On top of total households, this feature tells us within a certain area size, how many households are there. Since people living nearby are more likely target customers, the more densely populated neighborhood is a more ideal choice.
# * **One-person Households**: Number of the households that with only one person.
#   * One-person households are perfect target customers. Because cooking is no fun when alone. It is more likely this group of people will dine out or buy takeout.
#
#
# Demographic analysis is definitely essential to start narrowing down neighborhoods in Amsterdam. However, it is not the focus of this article. If you are interested in the full story (including demographic data analysis), please read [the full story](https://).

# %% [markdown]
# ### Conclude demographic analysis
#
# From studying and analysing demographic data, we chose 10 out of 65 neighborhoods in Amsterdam. The next step is to view all the remaining candidate neighborhoods on a map.

# %% [markdown]
# # 3. View candidate neighborhoods on a map
#
# We will use these tools to visualize information on a map:
# * [TomTom map](http://): map data
# * [folium](http://): map rendering library
#
# ### Load the information of the 10 remaining neighborhoods into a dataframe

# %%
# library to handle data in a vectorized manner
import numpy as np 
# library to load dataframe
import pandas as pd

# Matplotlib and associated plotting modules
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# %% [markdown]
# The CSV file that is loaded below is cleaned up based on analyzing demographic data. In [the full story](https://), I explained how to process the data from a larger dataset.

# %%
#Load the csv file.
df = pd.read_csv('https://dl.dropboxusercontent.com/s/3781fqm6w2i3gir/Amsterdam_top10.csv')
df
# Out:
#             Neighborhood  Total Residences  Total Households  \
# 0                Jordaan             19435             12985
# 1        Van Lennepbuurt              6990              4535
# 2             Nieuwmarkt              9765              6485
# 3              Oude Pijp             14820              9875
# 4            Nieuwe Pijp             12325              7905
# 5           Weesperzijde              5535              3470
# 6    Grachtengordel-West              6385              4110
# 7            Kinkerbuurt              6590              3950
# 8           Helmersbuurt              7410              4580
# 9  Frederik Hendrikbuurt              8435              5160
#
#    One-person Households  Population Density  \
# 0                   8625               23289
# 1                   3005               28005
# 2                   4285               13741
# 3                   6510               23353
# 4                   5015               23998
# 5                   2180               14984
# 6                   2570               14261
# 7                   2460               26135
# 8                   2835               22124
# 9                   3165               23520
#
#    Percentage of One-person Households        Lat       Lon
# 0                                66.42  52.374500  4.879491
# 1                                66.26  52.365144  4.867845
# 2                                66.08  52.372160  4.900096
# 3                                65.92  52.355216  4.894574
# 4                                63.44  52.351856  4.897728
# 5                                62.82  52.357900  4.906300
# 6                                62.53  52.370837  4.885478
# 7                                62.28  52.369167  4.866649
# 8                                61.90  52.363360  4.871285
# 9                                61.34  52.376956  4.874085

# %% [markdown]
# ## 3.1 Install and import folium

# %%
#pip install folium==0.9.1 #comment it out if folium is already installed

# %%
import folium # map rendering library

# %% [markdown]
# ## 3.1 Use TomTom Search API
#
# ### Acquire an API key
#
# Click the "Get Your Key" button in [this page](https://developer.tomtom.com/content/search-api-explorer) to acquire an API key.
#
# ### Load the TomTom API
#
# TomTom API offers multiple APIs, including the Search API. There is no need to load each API separately.

# %%
import requests
tomtom_api_keys = ["GIwKyhLAulUFbyy2kXQ0aTNdwOlmWUHd"] # max 2500 calls/day
api_key = tomtom_api_keys[0]

# %% [markdown]
# ### Get the lat lon of the center of map
#
# Define a function using [Geocoding feature in Search API](https://developer.tomtom.com/content/search-api-explorer#/Geocoding/get_search__versionNumber__geocode__query___ext_) to get lat/lon of the center of a city.

# %%
# Search for city: 
def SearchCity(api_key,City,Country):
    
    url = 'https://api.tomtom.com/search/2/search/'
    url += City + ', ' + Country
    url += '.json?limit=1&idxSet=Geo&key=' + api_key
    
    result = requests.get(url).json()
    
    GeoID = result['results'][0]['dataSources']['geometry']['id']
    position = result['results'][0]['position']
    
    return GeoID,position

# %%
# Use the SearchCity function to get the lat/lon of Amsterdam
Amsterdam_position = SearchCity(api_key, "Amsterdam", "Netherlands")
lat_amsterdam = Amsterdam_position[1]['lat']
lon_amsterdam = Amsterdam_position[1]['lon']
print("Center of Amsterdam lat/lon: (", lat_amsterdam, lon_amsterdam, ")")
# Out:
# Center of Amsterdam lat/lon: ( 52.37317 4.89066 )

# %% [markdown]
# ### 3.6.1. First Impression of the Candidate Neighborhoods
# [Back to top](#top)
#
# Visualize one feature (number of one-person households) to get an impression of the 10 candidate neighborhoods.

# %%
#Define a function to initialize any map using TomTom map.
def init_map(api_key=api_key, latitude=0, longitude=0, zoom=14, layer = "basic", style = "main"):
    """
    The initialise_map function initializes a clean TomTom map
    """
    
    maps_url = "http://{s}.api.tomtom.com/map/1/tile/"+layer+"/"+style+"/{z}/{x}/{y}.png?tileSize=512&key="
    TomTom_map = folium.Map(
        location = [latitude, longitude],  # on what coordinates [lat, lon] we want to initialise our map
        zoom_start = zoom,  # with what zoom level we want to initialize our map, from 0 to 22
        tiles = str(maps_url + api_key),
        attr = 'TomTom')
    
    return TomTom_map

# %% [markdown]
# #### Visualize one feature (number of one-person households) to get an impression of the 10 candidate neighborhoods.

# %%
#Visualize one feature (number of one-person households) to get an impression of the 10 candidate neighborhoods.
TomTom_map = init_map(latitude=lat_amsterdam, longitude=lon_amsterdam, zoom=13, layer = "hybrid")

# add markers to map
for lat, lon, neighborhood, oph in zip(df['Lat'], df['Lon'], df['Neighborhood'], df['One-person Households']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=oph/25,
        popup=label, 
        color='#FF7F0F', # Orange
        fill=True,
        fill_color='#FF7F0F',
        fill_opacity=0.3).add_to(TomTom_map)

TomTom_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3.6.2. Visualize More Features on the Map
#
# The above map gives us an impression of how the numbers of one-person households per neighborhood looks like.
#
# Now let's add three features to the map:
#
# 1. **Orange circles** represent the number of one-person households.
# 2. **Blue circles** represent the number of households in total.
# 3. **Green circles** represent the population density.
#
# As to the circles:
#
# * The center of the orange, green, and blue circles is the center of the neighborhood. Click the center of the circles to see the name of the neighborhood.
# * The radius of each circle represents the number of each feature.
#
# In order to show a more zoomed in map view, we re-adjust the center of the map.
#
# #### Re-adjust the center of the 10 candidate neighborhoods
#
# Based on the previous map visualization, we can see a better center of further analysis is this address: Prinsengracht 745A Amsterdam

# %%
url = "https://api.tomtom.com/search/2/geocode/Prinsengracht 745A Amsterdam.json?countrySet=NL&key=" + api_key
result = requests.get(url).json()

# %%
lat_center = result['results'][0]['position']['lat']
lon_center = result['results'][0]['position']['lon']
print(lat_center, lon_center)
# Out:
# 52.36425 4.88628

# %% [markdown]
# #### Draw the Map with One-person Households, Total Households, and Population Density.

# %%
TomTom_map = init_map(latitude=lat_center, longitude=lon_center, zoom=14, layer = "hybrid")

# add markers that represent one-person households to the map
for lat, lon, neighborhood, oph in zip(df['Lat'], df['Lon'], df['Neighborhood'], df['One-person Households']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=oph/25,
        popup=label,
        color='#FF7F0F', # Orange
        fill=True,
        fill_color='#FF7F0F', 
        fill_opacity=0.3
    ).add_to(TomTom_map)

# add markers that represent total households to the map
for lat, lon, neighborhood, households in zip(df['Lat'], df['Lon'], df['Neighborhood'], df['Total Households']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=households/25,
        popup=label,
        color='#1E77B4', # Blue
        fill=False
    ).add_to(TomTom_map)
    
# add markers that represent population density to the map
for lat, lon, neighborhood, density in zip(df['Lat'], df['Lon'], df['Neighborhood'], df['Population Density']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=density/100,
        popup=label,
        color='#2A9E2A', # Green
        fill=False
    ).add_to(TomTom_map)
TomTom_map.save('Neighborhood_demographic.html')
TomTom_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Learnings from the above data visualization
#
# As you can see, when we choose an ideal location to open the Chinese restaurant:
# * **The bigger the green circles the better.**
# * **The less difference between the size of the blue circles and the orange circles the better.**

# %% [markdown]
# ## 3.7. Conclusion of Demographic Data Analysis<a id='37'></a>
# [Back to top](#top)
#
# Through the above analysis, we have chosen **10** out of **65** neighborhoods in Amsterdam city proper as our candidate neighborhood to investigate further.
#
# In the next chapter we will further analyze the **10** neighborhoods by looking into the number of restaurants and the density of Chinese restaurants to further narrow down to **3 ~ 5** neighborhoods for future analysis.
#
# <br>
# <hr style="border: 1px solid orange;">

# %% [markdown]
# # 4. Explore the Surroundings<a id='4'></a>
# [Back to top](#top)
#
# (Add description of TomTom Search API)
#
# Now, we know where the remaining 10 neighborhoods locate and their geo-relationship. It's time to explore the surroundings. In the scope of the project, we will focus on only question to demonstrate the methodology:
#
#  * How many Chinese restaurants are already available in each neighborhood?
#
# ## 4.1. Question: How many Chinese restaurants are already available in each neighborhood?
#
# Use the [Search API explorer](https://developer.tomtom.com/content/search-api-explorer#/Search/get_search__versionNumber__categorySearch__query___ext_) to get the url. We will choose to store all search results in a JSON file.
#
# Some key variables:
#
# * Search radius: **radius**
# * Maximum number of search results: **limit**

# %%
search_radius = 3000
search_limit = 2000

# %%
url = ('https://api.tomtom.com/search/2/categorySearch/Chinese restaurant.json?countrySet=NL'
       +'&lat=52.364250&lon=4.886280&limit=2000&radius=3000&key=' + api_key)
result = requests.get(url).json()
result
# Out:
# {'summary': {'query': 'chinese restaurant',
#   'queryType': 'NON_NEAR',
#   'queryTime': 143,
#   'numResults': 73,
#   'offset': 0,
#   'totalResults': 73,
#   'fuzzyLevel': 1,
#   'geoBias': {'lat': 52.36425, 'lon': 4.88628}},
#  'results': [{'type': 'POI',
#    'id': 'NL/POI/p0/109857',
#    'score': 5.14904,
#    'dist': 150.32529954911772,
#    'info': 'search:ta:528009005857203-NL',
#    'poi': {'name': 'Taste Of Culture',
#     'phone': '+(31)-(20)-4271136',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.tasteofculture.net',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '139HS',
#     'streetName': 'Korte Leidsedwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017PZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Korte Leidsedwarsstraat 139HS, 1017PZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36311, 'lon': 4.88509},
#    'viewport': {'topLeftPoint': {'lat': 52.36401, 'lon': 4.88362},
#     'btmRightPoint': {'lat': 52.36221, 'lon': 4.88656}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36305, 'lon': 4.885}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/334858',
#    'score': 5.14904,
#    'dist': 140.3759846149783,
#    'info': 'search:ta:528009005858835-NL',
#    'poi': {'name': 'Mr Tongs',
#     'phone': '+(31)-(20)-6234829',
#     'categorySet': [{'id': 7315012}],
#     'url': 'mrtongs.eu',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '119',
#     'streetName': 'Korte Leidsedwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017PZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Korte Leidsedwarsstraat 119, 1017PZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36331, 'lon': 4.8849},
#    'viewport': {'topLeftPoint': {'lat': 52.36421, 'lon': 4.88343},
#     'btmRightPoint': {'lat': 52.36241, 'lon': 4.88637}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36323, 'lon': 4.88475}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/336748',
#    'score': 5.14904,
#    'dist': 162.5818780255306,
#    'info': 'search:ta:528009007894155-NL',
#    'poi': {'name': 'Full Moon Garden',
#     'phone': '+(31)-(20)-2382546',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.fullmoongarden.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '95',
#     'streetName': 'Leidsestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017NX',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Leidsestraat 95, 1017NX, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36456, 'lon': 4.88394},
#    'viewport': {'topLeftPoint': {'lat': 52.36546, 'lon': 4.88247},
#     'btmRightPoint': {'lat': 52.36366, 'lon': 4.88541}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36469, 'lon': 4.88377}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379367',
#    'score': 5.14904,
#    'dist': 162.5818780255306,
#    'info': 'search:ta:528009001037112-NL',
#    'poi': {'name': 'Yun Zhong',
#     'phone': '+(31)-(20)-4276809',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '95',
#     'streetName': 'Leidsestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017NX',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Leidsestraat 95, 1017NX, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36456, 'lon': 4.88394},
#    'viewport': {'topLeftPoint': {'lat': 52.36546, 'lon': 4.88247},
#     'btmRightPoint': {'lat': 52.36366, 'lon': 4.88541}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36469, 'lon': 4.88377}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379368',
#    'score': 5.14904,
#    'dist': 162.5818780255306,
#    'info': 'search:ta:528009001039227-NL',
#    'poi': {'name': 'Dim Sum Palace',
#     'phone': '+(31)-(20)-6262465',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '95',
#     'streetName': 'Leidsestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017NX',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Leidsestraat 95, 1017NX, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36456, 'lon': 4.88394},
#    'viewport': {'topLeftPoint': {'lat': 52.36546, 'lon': 4.88247},
#     'btmRightPoint': {'lat': 52.36366, 'lon': 4.88541}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36469, 'lon': 4.88377}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379431',
#    'score': 5.14904,
#    'dist': 179.2203370226465,
#    'info': 'search:ta:528009001014038-NL',
#    'poi': {'name': 'Dim Sum Court',
#     'phone': '+(31)-(20)-6444898',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '139-141',
#     'streetName': 'Korte Leidsedwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017PZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Korte Leidsedwarsstraat 139-141, 1017PZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36272, 'lon': 4.88545},
#    'viewport': {'topLeftPoint': {'lat': 52.36362, 'lon': 4.88398},
#     'btmRightPoint': {'lat': 52.36182, 'lon': 4.88692}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36303, 'lon': 4.88504}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/730704',
#    'score': 5.14904,
#    'dist': 152.21671373265633,
#    'info': 'search:ta:528009007985312-NL',
#    'poi': {'name': "Mr Tong's",
#     'phone': '+(31)-(20)-6234829',
#     'categorySet': [{'id': 7315012}],
#     'url': 'mrtongs.eu',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '119-121',
#     'streetName': 'Korte Leidsedwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017PZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Korte Leidsedwarsstraat 119-121, 1017PZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36333, 'lon': 4.88462},
#    'viewport': {'topLeftPoint': {'lat': 52.36423, 'lon': 4.88315},
#     'btmRightPoint': {'lat': 52.36243, 'lon': 4.88609}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36329, 'lon': 4.88466}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379606',
#    'score': 5.14897,
#    'dist': 374.38799538933324,
#    'info': 'search:ta:528001000025099-NL',
#    'poi': {'name': 'Dynasty',
#     'phone': '+(31)-(20)-6268400',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.restaurantdynasty.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '30',
#     'streetName': 'Reguliersdwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017BK',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Reguliersdwarsstraat 30, 1017BK, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36635, 'lon': 4.89059},
#    'viewport': {'topLeftPoint': {'lat': 52.36725, 'lon': 4.88912},
#     'btmRightPoint': {'lat': 52.36545, 'lon': 4.89206}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36643, 'lon': 4.89062}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379605',
#    'score': 5.14896,
#    'dist': 384.92008365625753,
#    'info': 'search:ta:528009007992231-NL',
#    'poi': {'name': 'Sichuan Food',
#     'phone': '+(31)-(20)-6269327',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.sichuanfood.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '35',
#     'streetName': 'Reguliersdwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017BK',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Reguliersdwarsstraat 35, 1017BK, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36652, 'lon': 4.89056},
#    'viewport': {'topLeftPoint': {'lat': 52.36742, 'lon': 4.88909},
#     'btmRightPoint': {'lat': 52.36562, 'lon': 4.89203}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36644, 'lon': 4.89054}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/113380',
#    'score': 5.14886,
#    'dist': 552.8413462533188,
#    'info': 'search:ta:528009008027878-NL',
#    'poi': {'name': 'Asian Kitchen',
#     'phone': '+(31)-(20)-6201816',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.asiankitchen.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '5A',
#     'streetName': 'Vijzelstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017HD',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Vijzelstraat 5A, 1017HD, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36656, 'lon': 4.89349},
#    'viewport': {'topLeftPoint': {'lat': 52.36746, 'lon': 4.89202},
#     'btmRightPoint': {'lat': 52.36566, 'lon': 4.89496}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36657, 'lon': 4.89331}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/336190',
#    'score': 5.14884,
#    'dist': 578.4293704087045,
#    'info': 'search:ta:528009008015005-NL',
#    'poi': {'name': 'Dim Sum Court',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '152',
#     'streetName': 'Rokin',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012LE',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Rokin 152, 1012LE, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.3679, 'lon': 4.89235},
#    'viewport': {'topLeftPoint': {'lat': 52.3688, 'lon': 4.89088},
#     'btmRightPoint': {'lat': 52.367, 'lon': 4.89382}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36812, 'lon': 4.8928}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379708',
#    'score': 5.14881,
#    'dist': 622.7171162865222,
#    'info': 'search:ta:528009001047378-NL',
#    'poi': {'name': 'Shanghai Noodle',
#     'phone': '+(31)-(20)-7712225',
#     'categorySet': [{'id': 7315012}],
#     'url': 'shanghainoodle.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '152',
#     'streetName': 'Rokin',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012LE',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Rokin 152, 1012LE, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36817, 'lon': 4.89283},
#    'viewport': {'topLeftPoint': {'lat': 52.36907, 'lon': 4.89136},
#     'btmRightPoint': {'lat': 52.36727, 'lon': 4.8943}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36813, 'lon': 4.89279}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379805',
#    'score': 5.1488,
#    'dist': 629.6398325219358,
#    'info': 'search:ta:528009001026979-NL',
#    'poi': {'name': 'Little Macau',
#     'phone': '+(31)-(6)-13778949',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '7',
#     'streetName': 'Schapensteeg',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017BG',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Schapensteeg 7, 1017BG, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36621, 'lon': 4.89498},
#    'viewport': {'topLeftPoint': {'lat': 52.36711, 'lon': 4.89351},
#     'btmRightPoint': {'lat': 52.36531, 'lon': 4.89645}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36594, 'lon': 4.89477}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379661',
#    'score': 5.14861,
#    'dist': 831.1915758032518,
#    'info': 'search:ta:528009007984885-NL',
#    'poi': {'name': 'Nam Kee',
#     'phone': '+(31)-(20)-6702336',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '4',
#     'streetName': 'Marie Heinekenplein',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1072',
#     'extendedPostalCode': '1072MH',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Marie Heinekenplein 4, 1072MH, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.3574, 'lon': 4.89118},
#    'viewport': {'topLeftPoint': {'lat': 52.3583, 'lon': 4.88971},
#     'btmRightPoint': {'lat': 52.3565, 'lon': 4.89265}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.35733, 'lon': 4.89109}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/730107',
#    'score': 5.1486,
#    'dist': 840.2306654562905,
#    'info': 'search:ta:528009007904346-NL',
#    'poi': {'name': 'One Dim Sum',
#     'phone': '+(31)-(20)-6893003',
#     'categorySet': [{'id': 7315012}],
#     'url': 'onedimsum.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '109',
#     'streetName': 'Overtoom',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1054',
#     'extendedPostalCode': '1054HC',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Overtoom 109, 1054HC, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36248, 'lon': 4.87425},
#    'viewport': {'topLeftPoint': {'lat': 52.36338, 'lon': 4.87278},
#     'btmRightPoint': {'lat': 52.36158, 'lon': 4.87572}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36242, 'lon': 4.87421}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/332888',
#    'score': 5.1485,
#    'dist': 925.506391417331,
#    'info': 'search:ta:528009001786257-NL',
#    'poi': {'name': 'Dim Sum Now',
#     'phone': '+(31)-(20)-8200808',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.dimsumnow.com',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '36',
#     'streetName': 'Ferdinand Bolstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1072',
#     'extendedPostalCode': '1072LA',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Ferdinand Bolstraat 36, 1072LA, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.35636, 'lon': 4.89062},
#    'viewport': {'topLeftPoint': {'lat': 52.35726, 'lon': 4.88915},
#     'btmRightPoint': {'lat': 52.35546, 'lon': 4.89209}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.35629, 'lon': 4.89056}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/726571',
#    'score': 5.14849,
#    'dist': 932.0603706544399,
#    'info': 'search:ta:528009007956163-NL',
#    'poi': {'name': 'FuLu Mandarijn Amsterdam',
#     'phone': '+(31)-(20)-6230885',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.mandarijnrokin.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '26',
#     'streetName': 'Rokin',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012KS',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Rokin 26, 1012KS, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37171, 'lon': 4.89254},
#    'viewport': {'topLeftPoint': {'lat': 52.37261, 'lon': 4.89107},
#     'btmRightPoint': {'lat': 52.37081, 'lon': 4.89401}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.3717, 'lon': 4.89285}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379122',
#    'score': 5.14846,
#    'dist': 963.2155633236454,
#    'info': 'search:ta:528009001040418-NL',
#    'poi': {'name': "Tea's Delight",
#     'phone': '+(31)-(20)-6161749',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.teasdelight.com',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '58',
#     'streetName': 'Kinkerstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1053',
#     'extendedPostalCode': '1053DZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Kinkerstraat 58, 1053DZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36753, 'lon': 4.87315},
#    'viewport': {'topLeftPoint': {'lat': 52.36843, 'lon': 4.87168},
#     'btmRightPoint': {'lat': 52.36663, 'lon': 4.87462}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36756, 'lon': 4.87307}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379789',
#    'score': 5.14835,
#    'dist': 1047.3602488504482,
#    'info': 'search:ta:528009007922725-NL',
#    'poi': {'name': 'Dragon City',
#     'phone': '+(31)-(20)-6231529',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '18',
#     'streetName': 'Damstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Damstraat 18, 1012JL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37217, 'lon': 4.89463},
#    'viewport': {'topLeftPoint': {'lat': 52.37307, 'lon': 4.89316},
#     'btmRightPoint': {'lat': 52.37127, 'lon': 4.8961}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37224, 'lon': 4.89469}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/735106',
#    'score': 5.14834,
#    'dist': 1054.2400155869339,
#    'info': 'search:ta:528009007840823-NL',
#    'poi': {'name': 'Chinese Claypot Restaurant',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '139',
#     'streetName': 'Damstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Damstraat 139, 1012JL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37222, 'lon': 4.89469},
#    'viewport': {'topLeftPoint': {'lat': 52.37312, 'lon': 4.89322},
#     'btmRightPoint': {'lat': 52.37132, 'lon': 4.89616}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37224, 'lon': 4.89471}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/733663',
#    'score': 5.14833,
#    'dist': 1064.0074530683178,
#    'info': 'search:ta:528009007943961-NL',
#    'poi': {'name': 'Albina',
#     'phone': '+(31)-(20)-6755135',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '69HS',
#     'streetName': 'Albert Cuypstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1072',
#     'extendedPostalCode': '1072CL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Albert Cuypstraat 69HS, 1072CL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.35493, 'lon': 4.88983},
#    'viewport': {'topLeftPoint': {'lat': 52.35583, 'lon': 4.88836},
#     'btmRightPoint': {'lat': 52.35403, 'lon': 4.8913}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.3549, 'lon': 4.88987}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/332552',
#    'score': 5.14832,
#    'dist': 1065.832234470697,
#    'info': 'search:ta:528009007948589-NL',
#    'poi': {'name': 'Asia Dam',
#     'phone': '+(31)-(20)-6222702',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '1A',
#     'streetName': 'Damstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Damstraat 1A, 1012JL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37249, 'lon': 4.8943},
#    'viewport': {'topLeftPoint': {'lat': 52.37339, 'lon': 4.89283},
#     'btmRightPoint': {'lat': 52.37159, 'lon': 4.89577}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.3724, 'lon': 4.89423}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379849',
#    'score': 5.1483,
#    'dist': 1079.306630175677,
#    'info': 'search:ta:528009007903488-NL',
#    'poi': {'name': 'Golden Chopsticks',
#     'phone': '+(31)-(20)-6207040',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.goldenchopsticks.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '1',
#     'streetName': 'Oude Doelenstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012ED',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Oude Doelenstraat 1, 1012ED, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37182, 'lon': 4.89623},
#    'viewport': {'topLeftPoint': {'lat': 52.37272, 'lon': 4.89476},
#     'btmRightPoint': {'lat': 52.37092, 'lon': 4.8977}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37175, 'lon': 4.89617}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379856',
#    'score': 5.1483,
#    'dist': 1079.3468261952437,
#    'info': 'search:ta:528001000024710-NL',
#    'poi': {'name': 'Oriental City',
#     'phone': '+(31)-(20)-6268352',
#     'categorySet': [{'id': 7315012}],
#     'url': 'oriental-city.com',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '177-179',
#     'streetName': 'Oudezijds Voorburgwal',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012EV',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Oudezijds Voorburgwal 177-179, 1012EV, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37184, 'lon': 4.89619},
#    'viewport': {'topLeftPoint': {'lat': 52.37274, 'lon': 4.89472},
#     'btmRightPoint': {'lat': 52.37094, 'lon': 4.89766}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37187, 'lon': 4.89613}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/728244',
#    'score': 5.14827,
#    'dist': 1104.3842131697304,
#    'info': 'search:ta:528009007951990-NL',
#    'poi': {'name': 'Golden Dragon Restaurant, Amsterdam',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetName': 'Warmoesstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JC',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Warmoesstraat, 1012JC, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37287, 'lon': 4.89436},
#    'viewport': {'topLeftPoint': {'lat': 52.37377, 'lon': 4.89289},
#     'btmRightPoint': {'lat': 52.37197, 'lon': 4.89583}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37286, 'lon': 4.89437}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379078',
#    'score': 5.14818,
#    'dist': 1165.8054884102785,
#    'info': 'search:ta:528009001021233-NL',
#    'poi': {'name': "Fan's Kitchen",
#     'phone': '+(31)-(20)-6167501',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.fanskitchen.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetName': 'Overtoom',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1054',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Overtoom, 1054, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36131, 'lon': 4.8698},
#    'viewport': {'topLeftPoint': {'lat': 52.36221, 'lon': 4.86833},
#     'btmRightPoint': {'lat': 52.36041, 'lon': 4.87127}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36131, 'lon': 4.86981}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379958',
#    'score': 5.14814,
#    'dist': 1190.0060467893245,
#    'info': 'search:ta:528009001023602-NL',
#    'poi': {'name': 'Ah-Lung',
#     'phone': '+(31)-(20)-6754949',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.ahlung-amsterdam.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetName': 'Govert Flinckstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1074',
#     'extendedPostalCode': '1074CA',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Govert Flinckstraat, 1074CA, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.35726, 'lon': 4.89955},
#    'viewport': {'topLeftPoint': {'lat': 52.35816, 'lon': 4.89808},
#     'btmRightPoint': {'lat': 52.35636, 'lon': 4.90102}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.35676, 'lon': 4.89994}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/334940',
#    'score': 5.14808,
#    'dist': 1231.066131863714,
#    'info': 'search:ta:528009007950951-NL',
#    'poi': {'name': 'Nieuw Peking',
#     'phone': '+(31)-(20)-6791691',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '166HS',
#     'streetName': 'Van Baerlestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1071',
#     'extendedPostalCode': '1071BH',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Van Baerlestraat 166HS, 1071BH, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.35353, 'lon': 4.88175},
#    'viewport': {'topLeftPoint': {'lat': 52.35443, 'lon': 4.88028},
#     'btmRightPoint': {'lat': 52.35263, 'lon': 4.88322}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.35354, 'lon': 4.88171}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379082',
#    'score': 5.14805,
#    'dist': 1248.406168687158,
#    'info': 'search:ta:528009005861486-NL',
#    'poi': {'name': 'Pagode',
#     'phone': '+(31)-(20)-6182043',
#     'categorySet': [{'id': 7315012}],
#     'url': 'restaurantpagode.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '74HS',
#     'streetName': 'Bilderdijkstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1053',
#     'extendedPostalCode': '1053KV',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Bilderdijkstraat 74HS, 1053KV, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36992, 'lon': 4.87041},
#    'viewport': {'topLeftPoint': {'lat': 52.37082, 'lon': 4.86894},
#     'btmRightPoint': {'lat': 52.36902, 'lon': 4.87188}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37, 'lon': 4.87039}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/730700',
#    'score': 5.14801,
#    'dist': 1272.273681599476,
#    'info': 'search:ta:528009007772485-NL',
#    'poi': {'name': 'Dim Sum Thing',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.foodhallen.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '51',
#     'streetName': 'Bellamyplein',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1053',
#     'extendedPostalCode': '1053AT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Bellamyplein 51, 1053AT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36707, 'lon': 4.86812},
#    'viewport': {'topLeftPoint': {'lat': 52.36797, 'lon': 4.86665},
#     'btmRightPoint': {'lat': 52.36617, 'lon': 4.86959}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36784, 'lon': 4.86789}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379707',
#    'score': 5.14794,
#    'dist': 1312.7844107603373,
#    'info': 'search:ta:528009001023396-NL',
#    'poi': {'name': 'Kam Kee',
#     'phone': '+(31)-(20)-6644831',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '119HS',
#     'streetName': 'Ceintuurbaan',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1072',
#     'extendedPostalCode': '1072EX',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Ceintuurbaan 119HS, 1072EX, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.35308, 'lon': 4.89254},
#    'viewport': {'topLeftPoint': {'lat': 52.35398, 'lon': 4.89107},
#     'btmRightPoint': {'lat': 52.35218, 'lon': 4.89401}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.35304, 'lon': 4.89266}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/336729',
#    'score': 5.14792,
#    'dist': 1324.3024783722142,
#    'info': 'search:ta:528009007935827-NL',
#    'poi': {'name': 'Yu Fung',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '49/HS',
#     'streetName': 'Van Woustraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1073',
#     'extendedPostalCode': '1073LN',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Van Woustraat 49/HS, 1073LN, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.35594, 'lon': 4.90025},
#    'viewport': {'topLeftPoint': {'lat': 52.35684, 'lon': 4.89878},
#     'btmRightPoint': {'lat': 52.35504, 'lon': 4.90172}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.356, 'lon': 4.90031}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/732929',
#    'score': 5.14781,
#    'dist': 1388.848079418198,
#    'info': 'search:ta:528009007730525-NL',
#    'poi': {'name': 'Hoi Tin',
#     'phone': '+(31)-(20)-6256451',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.restauranthoitin.com',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '122-124',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012AW',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 122-124, 1012AW, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37347, 'lon': 4.90008},
#    'viewport': {'topLeftPoint': {'lat': 52.37437, 'lon': 4.89861},
#     'btmRightPoint': {'lat': 52.37257, 'lon': 4.90155}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37339, 'lon': 4.90022}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379972',
#    'score': 5.1478,
#    'dist': 1392.8288007445046,
#    'info': 'search:ta:528009001017950-NL',
#    'poi': {'name': 'Hoi Tin',
#     'phone': '+(31)-(20)-6204472',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '122/124',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012BB',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 122/124, 1012BB, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37344, 'lon': 4.90022},
#    'viewport': {'topLeftPoint': {'lat': 52.37434, 'lon': 4.89875},
#     'btmRightPoint': {'lat': 52.37254, 'lon': 4.90169}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37344, 'lon': 4.90022}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379969',
#    'score': 5.14779,
#    'dist': 1402.6513825950976,
#    'info': 'search:ta:528009001032921-NL',
#    'poi': {'name': 'Tea Corner Di Shue Fang',
#     'phone': '+(31)-(20)-4202357',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '118',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012AT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 118, 1012AT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37361, 'lon': 4.90013},
#    'viewport': {'topLeftPoint': {'lat': 52.37451, 'lon': 4.89866},
#     'btmRightPoint': {'lat': 52.37271, 'lon': 4.9016}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37361, 'lon': 4.90022}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/380011',
#    'score': 5.14778,
#    'dist': 1407.857596108232,
#    'info': 'search:ta:528009000044224-NL',
#    'poi': {'name': 'New King',
#     'phone': '+(31)-(20)-6252180',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.newking.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '115-117',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012AV',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 115-117, 1012AV, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37359, 'lon': 4.90028},
#    'viewport': {'topLeftPoint': {'lat': 52.37449, 'lon': 4.89881},
#     'btmRightPoint': {'lat': 52.37269, 'lon': 4.90175}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37359, 'lon': 4.90022}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/729336',
#    'score': 5.14778,
#    'dist': 1403.7768175127085,
#    'info': 'search:ta:528009007902711-NL',
#    'poi': {'name': 'Nam Kee Nieuwmarkt',
#     'phone': '+(31)-(20)-6392848',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.namkee.net',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '117',
#     'streetName': 'Geldersekade',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1011',
#     'extendedPostalCode': '1011EN',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Geldersekade 117, 1011EN, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37299, 'lon': 4.9012},
#    'viewport': {'topLeftPoint': {'lat': 52.37389, 'lon': 4.89973},
#     'btmRightPoint': {'lat': 52.37209, 'lon': 4.90267}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37302, 'lon': 4.90103}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379981',
#    'score': 5.14777,
#    'dist': 1410.5043629742815,
#    'info': 'search:ta:528009001028689-NL',
#    'poi': {'name': 'New King',
#     'phone': '+(31)-(20)-6252180',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.newking.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '115',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012AT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 115, 1012AT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37365, 'lon': 4.90023},
#    'viewport': {'topLeftPoint': {'lat': 52.37455, 'lon': 4.89876},
#     'btmRightPoint': {'lat': 52.37275, 'lon': 4.9017}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37364, 'lon': 4.90022}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379974',
#    'score': 5.14775,
#    'dist': 1420.8724839065828,
#    'info': 'search:ta:528009001047367-NL',
#    'poi': {'name': 'Dim Sum Court',
#     'phone': '+(31)-(20)-6381249',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '109',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012AV',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 109, 1012AV, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37377, 'lon': 4.90024},
#    'viewport': {'topLeftPoint': {'lat': 52.37467, 'lon': 4.89877},
#     'btmRightPoint': {'lat': 52.37287, 'lon': 4.90171}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37379, 'lon': 4.90022}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/727302',
#    'score': 5.14775,
#    'dist': 1422.8495194109862,
#    'info': 'search:ta:528009007940552-NL',
#    'poi': {'name': 'Dim Sum Court',
#     'phone': '+(31)-(20)-6381466',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '109A',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012AT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 109A, 1012AT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37375, 'lon': 4.90032},
#    'viewport': {'topLeftPoint': {'lat': 52.37465, 'lon': 4.89885},
#     'btmRightPoint': {'lat': 52.37285, 'lon': 4.90179}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37376, 'lon': 4.90022}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/734012',
#    'score': 5.14775,
#    'dist': 1420.4629378706118,
#    'info': 'search:ta:528009007999076-NL',
#    'poi': {'name': 'Nam Kee',
#     'phone': '+(31)-(20)-6243470',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.namkee.net',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '111-113',
#     'streetName': 'Zeedijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012AT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Zeedijk 111-113, 1012AT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37371, 'lon': 4.90034},
# ...
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '270',
#     'streetName': 'Van Hallstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1051',
#     'extendedPostalCode': '1051HE',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Van Hallstraat 270, 1051HE, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.3793, 'lon': 4.87152},
#    'viewport': {'topLeftPoint': {'lat': 52.3802, 'lon': 4.87005},
#     'btmRightPoint': {'lat': 52.3784, 'lon': 4.87299}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37942, 'lon': 4.87183}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/733711',
#    'score': 5.14652,
#    'dist': 1984.5472801728429,
#    'info': 'search:ta:528009005861336-NL',
#    'poi': {'name': "Panda's Kitchen",
#     'phone': '+(31)-(20)-7372236',
#     'categorySet': [{'id': 7315012}],
#     'url': 'pandaskitchen.nl/',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '30',
#     'streetName': 'Haarlemmerdijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1013',
#     'extendedPostalCode': '1013JC',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Haarlemmerdijk 30, 1013JC, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.38205, 'lon': 4.88841},
#    'viewport': {'topLeftPoint': {'lat': 52.38295, 'lon': 4.88694},
#     'btmRightPoint': {'lat': 52.38115, 'lon': 4.88988}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.38202, 'lon': 4.88836}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/378903',
#    'score': 5.14629,
#    'dist': 2069.553332173192,
#    'info': 'search:ta:528009001034556-NL',
#    'poi': {'name': 'Golden Pauw',
#     'phone': '+(31)-(20)-6188857',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '11',
#     'streetName': 'Jan Evertsenstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1057',
#     'extendedPostalCode': '1057BL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Jan Evertsenstraat 11, 1057BL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37136, 'lon': 4.85811},
#    'viewport': {'topLeftPoint': {'lat': 52.37226, 'lon': 4.85664},
#     'btmRightPoint': {'lat': 52.37046, 'lon': 4.85958}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37138, 'lon': 4.85845}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/337215',
#    'score': 5.14627,
#    'dist': 2077.340593465047,
#    'info': 'search:ta:528009007896325-NL',
#    'poi': {'name': 'Long Chie',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '9hs',
#     'streetName': 'Tweede Nassaustraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1052',
#     'extendedPostalCode': '1052BJ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Tweede Nassaustraat 9hs, 1052BJ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.38231, 'lon': 4.87845},
#    'viewport': {'topLeftPoint': {'lat': 52.38321, 'lon': 4.87698},
#     'btmRightPoint': {'lat': 52.38141, 'lon': 4.87992}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.38229, 'lon': 4.87859}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379623',
#    'score': 5.14623,
#    'dist': 2092.199775540439,
#    'info': 'search:ta:528009001025001-NL',
#    'poi': {'name': 'Oceania',
#     'phone': '+(31)-(20)-6738907',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.restaurantoceania.nl/',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '71/77',
#     'streetName': 'Scheldestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1078',
#     'extendedPostalCode': '1078GH',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Scheldestraat 71/77, 1078GH, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.34565, 'lon': 4.89093},
#    'viewport': {'topLeftPoint': {'lat': 52.34655, 'lon': 4.88946},
#     'btmRightPoint': {'lat': 52.34475, 'lon': 4.8924}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.34556, 'lon': 4.89092}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/378936',
#    'score': 5.14622,
#    'dist': 2097.8687393630908,
#    'info': 'search:ta:528009000782865-NL',
#    'poi': {'name': 'Wanica Exotics',
#     'phone': '+(31)-(20)-6898949',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '88',
#     'streetName': 'Jan van Galenstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1056',
#     'extendedPostalCode': '1056CD',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Jan van Galenstraat 88, 1056CD, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37495, 'lon': 4.86083},
#    'viewport': {'topLeftPoint': {'lat': 52.37585, 'lon': 4.85936},
#     'btmRightPoint': {'lat': 52.37405, 'lon': 4.8623}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37496, 'lon': 4.86084}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/729742',
#    'score': 5.14616,
#    'dist': 2117.994441659426,
#    'info': 'search:ta:528009007995648-NL',
#    'poi': {'name': 'Chinese Restaurant Oceania',
#     'phone': '+(31)-(20)-6738907',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.restaurantoceania.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '77',
#     'streetName': 'Scheldestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1078',
#     'extendedPostalCode': '1078GG',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Scheldestraat 77, 1078GG, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.34544, 'lon': 4.89119},
#    'viewport': {'topLeftPoint': {'lat': 52.34634, 'lon': 4.88972},
#     'btmRightPoint': {'lat': 52.34454, 'lon': 4.89266}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.34545, 'lon': 4.8909}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/378918',
#    'score': 5.14603,
#    'dist': 2165.220475901463,
#    'info': 'search:ta:528009001038086-NL',
#    'poi': {'name': 'Wah Do',
#     'phone': '+(31)-(20)-6189003',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '64',
#     'streetName': 'Bestevâerstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1056',
#     'extendedPostalCode': '1056HJ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Bestevâerstraat 64, 1056HJ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37502, 'lon': 4.85971},
#    'viewport': {'topLeftPoint': {'lat': 52.37592, 'lon': 4.85824},
#     'btmRightPoint': {'lat': 52.37412, 'lon': 4.86118}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.375, 'lon': 4.85954}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/727703',
#    'score': 5.14559,
#    'dist': 2317.2754554628914,
#    'info': 'search:ta:528009007870200-NL',
#    'poi': {'name': 'Tai Wan',
#     'phone': '+(31)-(20)-6719221',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '102',
#     'streetName': 'Maasstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1078',
#     'extendedPostalCode': '1078HG',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Maasstraat 102, 1078HG, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.34414, 'lon': 4.89523},
#    'viewport': {'topLeftPoint': {'lat': 52.34504, 'lon': 4.89376},
#     'btmRightPoint': {'lat': 52.34324, 'lon': 4.8967}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.34419, 'lon': 4.89548}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/335161',
#    'score': 5.14539,
#    'dist': 2386.0405357340155,
#    'info': 'search:ta:528009008007946-NL',
#    'poi': {'name': 'Dumplings',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '60',
#     'streetName': 'Nassauplein',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1052',
#     'extendedPostalCode': '1052AH',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Nassauplein 60, 1052AH, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.38546, 'lon': 4.88095},
#    'viewport': {'topLeftPoint': {'lat': 52.38636, 'lon': 4.87948},
#     'btmRightPoint': {'lat': 52.38456, 'lon': 4.88242}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.38543, 'lon': 4.88133}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/112712',
#    'score': 5.14538,
#    'dist': 2389.0827078444063,
#    'info': 'search:ta:528009007756448-NL',
#    'poi': {'name': 'Dragon I',
#     'phone': '+(31)-(20)-7706420',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.dragoni-restaurant.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '154',
#     'streetName': 'Amstelveenseweg',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1075',
#     'extendedPostalCode': '1075VT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Amstelveenseweg 154, 1075VT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.35367, 'lon': 4.85566},
#    'viewport': {'topLeftPoint': {'lat': 52.35457, 'lon': 4.85419},
#     'btmRightPoint': {'lat': 52.35277, 'lon': 4.85713}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.35368, 'lon': 4.85582}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/378829',
#    'score': 5.14513,
#    'dist': 2469.3508613539593,
#    'info': 'search:ta:528009008012342-NL',
#    'poi': {'name': 'Jade Garden',
#     'phone': '+(31)-(20)-6183224',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '28',
#     'streetName': 'Mercatorplein',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1057',
#     'extendedPostalCode': '1057CB',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Mercatorplein 28, 1057CB, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36993, 'lon': 4.85112},
#    'viewport': {'topLeftPoint': {'lat': 52.37083, 'lon': 4.84965},
#     'btmRightPoint': {'lat': 52.36903, 'lon': 4.85259}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36994, 'lon': 4.85131}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/378895',
#    'score': 5.14377,
#    'dist': 2866.457991358385,
#    'info': 'search:ta:528001000026423-NL',
#    'poi': {'name': 'New San Kong',
#     'phone': '+(31)-(20)-6641138',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '338',
#     'streetName': 'Amstelveenseweg',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1076',
#     'extendedPostalCode': '1076CS',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Amstelveenseweg 338, 1076CS, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.34552, 'lon': 4.85728},
#    'viewport': {'topLeftPoint': {'lat': 52.34642, 'lon': 4.85581},
#     'btmRightPoint': {'lat': 52.34462, 'lon': 4.85875}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.34553, 'lon': 4.85752}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/380252',
#    'score': 5.1436,
#    'dist': 2911.8506000972707,
#    'info': 'search:ta:528009001045473-NL',
#    'poi': {'name': 'Mi Lobie',
#     'phone': '+(31)-(20)-6928950',
#     'categorySet': [{'id': 7315012}],
#     'url': 'mi-lobie.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'restaurant'},
#        {'nameLocale': 'en-US', 'name': 'chinese'}]}]},
#    'address': {'streetNumber': '505',
#     'streetName': 'Eerste van Swindenstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1093',
#     'extendedPostalCode': '1093GB',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Eerste van Swindenstraat 505, 1093GB, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36321, 'lon': 4.92913},
#    'viewport': {'topLeftPoint': {'lat': 52.36411, 'lon': 4.92766},
#     'btmRightPoint': {'lat': 52.36231, 'lon': 4.9306}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36303, 'lon': 4.92923}}]}]}

# %% [markdown]
# ## 4.2. Show all the Chinese restaurants within 3.5 km on the map
#
# We can learn from the above JSON file that the following information is essential to show Chinese Restaurants on the map:
#
# * position
# * name

# %%
# add a grey circle to represent the search radius
folium.Circle(
    [lat_center, lon_center],
    radius=search_radius,
    color='#004B7F', # Navy
    opacity=0.3,
    fill = False
).add_to(TomTom_map)

# Add POIs one by one to the map
for poi in result['results']:
    folium.Marker(location=tuple(poi['position'].values()),
                  popup=str(poi['poi']['name']), 
                  icon=folium.Icon(color='blue', icon='glyphicon-star')
                  #icon=icon
             ).add_to(TomTom_map)
TomTom_map.save('POI_ChineseRestaurant.html')
TomTom_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Legends of the above map
#
# 1. **Blue markers**: Chinese restaurants.
# 2. **Orange circles**: the number of one-person households.
# 3. **Blue circles**: the number of households in total.
# 4. **Green circles**: the population density.
# 5. **Grey circle**: the search radius.

# %% [markdown]
# ## 4.3. Cluster the POIs
#
# For this analysis, it is easier to see ther number of restaurant in an area. Let's see if clustering POIs makes more sense.

# %%
from folium.plugins import MarkerCluster

# %%
# Define the marker cluster
mc = MarkerCluster()

# add a grey circle to represent the search radius
folium.Circle(
    [lat_center, lon_center],
    radius=search_radius,
    color='#004B7F', # Navy
    opacity=0.3,
    fill = False
).add_to(TomTom_map)

# Add POIs one by one to the map
for poi in result['results']:
    mc.add_child(
        folium.Marker(
            location=tuple(poi['position'].values()),
            popup=str(poi['poi']['name'])
    ))
 
TomTom_map.add_child(mc)
TomTom_map.save('POI_Clustered.html')
TomTom_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Zoom in and out the map to observe how the clusters react.

# %% [markdown]
# ### Learnings from the above map
#
# Our criteria to further narrow down our choice of neighborhoods are as such:
#
# * There must be at least one existing Chinese restaurant in or near the neighborhood.<br>
#   Because if there isn't at least one Chinese restaurant, it might mean that there isn't such demand. Opening a Chinese restaurant without understanding why there isn't any existing ones would be more risky.
# * There cannot more than 10 existing Chinese restaurants.<br>
#   The more existing Chinese restaurants means more competition.
#
# If we apply the criteria, from the above map, we can exclude these neighborhoods:
#
# * Too many existing Chinese restaurants
#   * Nieuwmarkt
# * No existing Chinese restaurant in or near the neighborhood
#   * Weesperzijde
#   * Frederik Hendrikbuurt
#   * Grachtengordel-West
#   * Nieuwe Pijp
#
# ### The remaining neighborhoods that we will investigate further are:
# * Jordaan
# * Van Lennepbuurt
# * Oude Pijp
# * Kinkerbuurt
# * Helmersbuurt

# %% [markdown]
# # 5. In-depth Analysis of One Neighborhood - Jordaan<a id='43'></a>
# [Back to top](#top)
#
# Let's use _Jordaan_ as an example to show how we look into one particular candidate neighborhood.
#
# ## 5.1. Draw the area of the neighborhood on the map

# %%
area_name = 'Jordaan'

# %% [markdown]
# Define a function to get polygon of a given GeoID.

# %%
# get polygon of GeoID: 
def getPolygon(api_key,GeoID,zoomLevel):
    
    url = 'https://api.tomtom.com/search/2/additionalData.json?geometries=' + GeoID
    url += '&geometriesZoom=' + str(zoomLevel)
    url += '&key=' + api_key
    
    result = requests.get(url).json()    
    GeoJson = result['additionalData'][0]['geometryData']
    
    return GeoJson

# %%
# Search City:
GeoID, position = SearchCity(api_key, area_name ,'Amsterdam')

# %%
lat_area = position['lat']
lon_area = position['lon']
print("The center of the neighborhood is: (", lat_area, ", ", lon_area, ")")
# Out:
# The center of the neighborhood is: ( 52.37329 ,  4.87992 )

# %% [markdown]
# ### Draw the polygon

# %%
# Get Polygon of city:
Polygon = getPolygon(api_key,GeoID,22)

# %%
map_url = 'http://{s}.api.tomtom.com/map/1/tile/basic/main/{z}/{x}/{y}.png?view=Unified&key=' + api_key

TomTom_map = folium.Map(
   location=[lat_area, lon_area],
   zoom_start=14,
   tiles= map_url,
   attr='TomTom')

# add polygons to a map
folium.GeoJson(
    Polygon).add_to(TomTom_map)

TomTom_map.save('Area.html')
TomTom_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5.2. Show Chinese restaurants in the neighborhood
#
# ### Search for the Chinese restaurant using the search API
#
# Set the search radius to 1.2 km to cover the entire neighborhood.

# %%
url = ('https://api.tomtom.com/search/2/categorySearch/Chinese restaurant.json?countrySet=NL'
       +'&lat=52.37329&lon=4.87992&limit=2000&radius=1200&key=' + api_key)
result = requests.get(url).json()
result
# Out:
# {'summary': {'query': 'chinese restaurant',
#   'queryType': 'NON_NEAR',
#   'queryTime': 63,
#   'numResults': 28,
#   'offset': 0,
#   'totalResults': 28,
#   'fuzzyLevel': 1,
#   'geoBias': {'lat': 52.37329, 'lon': 4.87992}},
#  'results': [{'type': 'POI',
#    'id': 'NL/POI/p0/379281',
#    'score': 5.1489,
#    'dist': 489.23055133883616,
#    'info': 'search:ta:528009001019356-NL',
#    'poi': {'name': 'Kam Wah',
#     'phone': '+(31)-(20)-6268230',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '18',
#     'streetName': 'Tweede Anjeliersdwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1015',
#     'extendedPostalCode': '1015NS',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Tweede Anjeliersdwarsstraat 18, 1015NS, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37757, 'lon': 4.88159},
#    'viewport': {'topLeftPoint': {'lat': 52.37847, 'lon': 4.88012},
#     'btmRightPoint': {'lat': 52.37667, 'lon': 4.88306}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37759, 'lon': 4.88161}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379082',
#    'score': 5.1487,
#    'dist': 746.49108536263,
#    'info': 'search:ta:528009005861486-NL',
#    'poi': {'name': 'Pagode',
#     'phone': '+(31)-(20)-6182043',
#     'categorySet': [{'id': 7315012}],
#     'url': 'restaurantpagode.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '74HS',
#     'streetName': 'Bilderdijkstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1053',
#     'extendedPostalCode': '1053KV',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Bilderdijkstraat 74HS, 1053KV, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36992, 'lon': 4.87041},
#    'viewport': {'topLeftPoint': {'lat': 52.37082, 'lon': 4.86894},
#     'btmRightPoint': {'lat': 52.36902, 'lon': 4.87188}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37, 'lon': 4.87039}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379122',
#    'score': 5.14865,
#    'dist': 788.3333426970928,
#    'info': 'search:ta:528009001040418-NL',
#    'poi': {'name': "Tea's Delight",
#     'phone': '+(31)-(20)-6161749',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.teasdelight.com',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '58',
#     'streetName': 'Kinkerstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1053',
#     'extendedPostalCode': '1053DZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Kinkerstraat 58, 1053DZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36753, 'lon': 4.87315},
#    'viewport': {'topLeftPoint': {'lat': 52.36843, 'lon': 4.87168},
#     'btmRightPoint': {'lat': 52.36663, 'lon': 4.87462}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36756, 'lon': 4.87307}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379101',
#    'score': 5.14856,
#    'dist': 878.4847666509482,
#    'info': 'search:ta:528009000220139-NL',
#    'poi': {'name': 'Fong Ling',
#     'phone': '+(31)-(20)-6827734',
#     'categorySet': [{'id': 7315012}],
#     'url': 'fongling-amsterdam.nl/',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '270',
#     'streetName': 'Van Hallstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1051',
#     'extendedPostalCode': '1051HE',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Van Hallstraat 270, 1051HE, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.3793, 'lon': 4.87152},
#    'viewport': {'topLeftPoint': {'lat': 52.3802, 'lon': 4.87005},
#     'btmRightPoint': {'lat': 52.3784, 'lon': 4.87299}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37942, 'lon': 4.87183}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/726571',
#    'score': 5.14856,
#    'dist': 874.5675511347196,
#    'info': 'search:ta:528009007956163-NL',
#    'poi': {'name': 'FuLu Mandarijn Amsterdam',
#     'phone': '+(31)-(20)-6230885',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.mandarijnrokin.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '26',
#     'streetName': 'Rokin',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012KS',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Rokin 26, 1012KS, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37171, 'lon': 4.89254},
#    'viewport': {'topLeftPoint': {'lat': 52.37261, 'lon': 4.89107},
#     'btmRightPoint': {'lat': 52.37081, 'lon': 4.89401}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.3717, 'lon': 4.89285}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379423',
#    'score': 5.14845,
#    'dist': 972.1711984876424,
#    'info': 'search:ta:528009001017161-NL',
#    'poi': {'name': 'Lucky House',
#     'phone': '+(31)-(20)-6209295',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.Lucky-House.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '22HS',
#     'streetName': 'Willemsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1015',
#     'extendedPostalCode': '1015HW',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Willemsstraat 22HS, 1015HW, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.38136, 'lon': 4.88543},
#    'viewport': {'topLeftPoint': {'lat': 52.38226, 'lon': 4.88396},
#     'btmRightPoint': {'lat': 52.38046, 'lon': 4.8869}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.38136, 'lon': 4.88541}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/332552',
#    'score': 5.14844,
#    'dist': 980.2570529396645,
#    'info': 'search:ta:528009007948589-NL',
#    'poi': {'name': 'Asia Dam',
#     'phone': '+(31)-(20)-6222702',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '1A',
#     'streetName': 'Damstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Damstraat 1A, 1012JL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37249, 'lon': 4.8943},
#    'viewport': {'topLeftPoint': {'lat': 52.37339, 'lon': 4.89283},
#     'btmRightPoint': {'lat': 52.37159, 'lon': 4.89577}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.3724, 'lon': 4.89423}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/728244',
#    'score': 5.14843,
#    'dist': 981.3932639950411,
#    'info': 'search:ta:528009007951990-NL',
#    'poi': {'name': 'Golden Dragon Restaurant, Amsterdam',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetName': 'Warmoesstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JC',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Warmoesstraat, 1012JC, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37287, 'lon': 4.89436},
#    'viewport': {'topLeftPoint': {'lat': 52.37377, 'lon': 4.89289},
#     'btmRightPoint': {'lat': 52.37197, 'lon': 4.89583}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37286, 'lon': 4.89437}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/336748',
#    'score': 5.1484,
#    'dist': 1008.3715375294602,
#    'info': 'search:ta:528009007894155-NL',
#    'poi': {'name': 'Full Moon Garden',
#     'phone': '+(31)-(20)-2382546',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.fullmoongarden.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '95',
#     'streetName': 'Leidsestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017NX',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Leidsestraat 95, 1017NX, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36456, 'lon': 4.88394},
#    'viewport': {'topLeftPoint': {'lat': 52.36546, 'lon': 4.88247},
#     'btmRightPoint': {'lat': 52.36366, 'lon': 4.88541}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36469, 'lon': 4.88377}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/337215',
#    'score': 5.1484,
#    'dist': 1007.9308832294982,
#    'info': 'search:ta:528009007896325-NL',
#    'poi': {'name': 'Long Chie',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '9hs',
#     'streetName': 'Tweede Nassaustraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1052',
#     'extendedPostalCode': '1052BJ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Tweede Nassaustraat 9hs, 1052BJ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.38231, 'lon': 4.87845},
#    'viewport': {'topLeftPoint': {'lat': 52.38321, 'lon': 4.87698},
#     'btmRightPoint': {'lat': 52.38141, 'lon': 4.87992}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.38229, 'lon': 4.87859}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379367',
#    'score': 5.1484,
#    'dist': 1008.3715375294602,
#    'info': 'search:ta:528009001037112-NL',
#    'poi': {'name': 'Yun Zhong',
#     'phone': '+(31)-(20)-4276809',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '95',
#     'streetName': 'Leidsestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017NX',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Leidsestraat 95, 1017NX, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36456, 'lon': 4.88394},
#    'viewport': {'topLeftPoint': {'lat': 52.36546, 'lon': 4.88247},
#     'btmRightPoint': {'lat': 52.36366, 'lon': 4.88541}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36469, 'lon': 4.88377}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379368',
#    'score': 5.1484,
#    'dist': 1008.3715375294602,
#    'info': 'search:ta:528009001039227-NL',
#    'poi': {'name': 'Dim Sum Palace',
#     'phone': '+(31)-(20)-6262465',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '95',
#     'streetName': 'Leidsestraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017NX',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Leidsestraat 95, 1017NX, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36456, 'lon': 4.88394},
#    'viewport': {'topLeftPoint': {'lat': 52.36546, 'lon': 4.88247},
#     'btmRightPoint': {'lat': 52.36366, 'lon': 4.88541}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36469, 'lon': 4.88377}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379789',
#    'score': 5.1484,
#    'dist': 1006.3543811654749,
#    'info': 'search:ta:528009007922725-NL',
#    'poi': {'name': 'Dragon City',
#     'phone': '+(31)-(20)-6231529',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '18',
#     'streetName': 'Damstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Damstraat 18, 1012JL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37217, 'lon': 4.89463},
#    'viewport': {'topLeftPoint': {'lat': 52.37307, 'lon': 4.89316},
#     'btmRightPoint': {'lat': 52.37127, 'lon': 4.8961}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37224, 'lon': 4.89469}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/735106',
#    'score': 5.1484,
#    'dist': 1009.7256529322829,
#    'info': 'search:ta:528009007840823-NL',
#    'poi': {'name': 'Chinese Claypot Restaurant',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '139',
#     'streetName': 'Damstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012JL',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Damstraat 139, 1012JL, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37222, 'lon': 4.89469},
#    'viewport': {'topLeftPoint': {'lat': 52.37312, 'lon': 4.89322},
#     'btmRightPoint': {'lat': 52.37132, 'lon': 4.89616}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37224, 'lon': 4.89471}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/336190',
#    'score': 5.14836,
#    'dist': 1035.0548642764181,
#    'info': 'search:ta:528009008015005-NL',
#    'poi': {'name': 'Dim Sum Court',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '152',
#     'streetName': 'Rokin',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012LE',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Rokin 152, 1012LE, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.3679, 'lon': 4.89235},
#    'viewport': {'topLeftPoint': {'lat': 52.3688, 'lon': 4.89088},
#     'btmRightPoint': {'lat': 52.367, 'lon': 4.89382}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36812, 'lon': 4.8928}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379605',
#    'score': 5.14835,
#    'dist': 1043.3141252646542,
#    'info': 'search:ta:528009007992231-NL',
#    'poi': {'name': 'Sichuan Food',
#     'phone': '+(31)-(20)-6269327',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.sichuanfood.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '35',
#     'streetName': 'Reguliersdwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017BK',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Reguliersdwarsstraat 35, 1017BK, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36652, 'lon': 4.89056},
#    'viewport': {'topLeftPoint': {'lat': 52.36742, 'lon': 4.88909},
#     'btmRightPoint': {'lat': 52.36562, 'lon': 4.89203}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36644, 'lon': 4.89054}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379708',
#    'score': 5.14835,
#    'dist': 1045.1358571040678,
#    'info': 'search:ta:528009001047378-NL',
#    'poi': {'name': 'Shanghai Noodle',
#     'phone': '+(31)-(20)-7712225',
#     'categorySet': [{'id': 7315012}],
#     'url': 'shanghainoodle.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '152',
#     'streetName': 'Rokin',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012LE',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Rokin 152, 1012LE, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36817, 'lon': 4.89283},
#    'viewport': {'topLeftPoint': {'lat': 52.36907, 'lon': 4.89136},
#     'btmRightPoint': {'lat': 52.36727, 'lon': 4.8943}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36813, 'lon': 4.89279}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379606',
#    'score': 5.14833,
#    'dist': 1058.4283896063323,
#    'info': 'search:ta:528001000025099-NL',
#    'poi': {'name': 'Dynasty',
#     'phone': '+(31)-(20)-6268400',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.restaurantdynasty.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '30',
#     'streetName': 'Reguliersdwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017BK',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Reguliersdwarsstraat 30, 1017BK, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36635, 'lon': 4.89059},
#    'viewport': {'topLeftPoint': {'lat': 52.36725, 'lon': 4.88912},
#     'btmRightPoint': {'lat': 52.36545, 'lon': 4.89206}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36643, 'lon': 4.89062}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/730700',
#    'score': 5.14833,
#    'dist': 1058.366544117491,
#    'info': 'search:ta:528009007772485-NL',
#    'poi': {'name': 'Dim Sum Thing',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.foodhallen.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '51',
#     'streetName': 'Bellamyplein',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1053',
#     'extendedPostalCode': '1053AT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Bellamyplein 51, 1053AT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36707, 'lon': 4.86812},
#    'viewport': {'topLeftPoint': {'lat': 52.36797, 'lon': 4.86665},
#     'btmRightPoint': {'lat': 52.36617, 'lon': 4.86959}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36784, 'lon': 4.86789}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/336269',
#    'score': 5.1483,
#    'dist': 1085.81935786359,
#    'info': 'search:ta:528009007796069-NL',
#    'poi': {'name': 'Royal Mandarin',
#     'categorySet': [{'id': 7315012}],
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '97',
#     'streetName': 'Haarlemmerstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1013',
#     'extendedPostalCode': '1013EM',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Haarlemmerstraat 97, 1013EM, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.38051, 'lon': 4.89069},
#    'viewport': {'topLeftPoint': {'lat': 52.38141, 'lon': 4.88922},
#     'btmRightPoint': {'lat': 52.37961, 'lon': 4.89216}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.38062, 'lon': 4.89084}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379820',
#    'score': 5.14828,
#    'dist': 1099.2067229739832,
#    'info': 'search:ta:528009001042706-NL',
#    'poi': {'name': 'Yu Family Kitchen',
#     'phone': '+(31)-(20)-4209177',
#     'categorySet': [{'id': 7315012}],
#     'url': 'yufamilykitchen.strikingly.com',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetName': 'Kolksteeg',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012PT',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Kolksteeg, 1012PT, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37617, 'lon': 4.89541},
#    'viewport': {'topLeftPoint': {'lat': 52.37707, 'lon': 4.89394},
#     'btmRightPoint': {'lat': 52.37527, 'lon': 4.89688}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37616, 'lon': 4.89541}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379849',
#    'score': 5.14825,
#    'dist': 1119.2425162395587,
#    'info': 'search:ta:528009007903488-NL',
#    'poi': {'name': 'Golden Chopsticks',
#     'phone': '+(31)-(20)-6207040',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.goldenchopsticks.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '1',
#     'streetName': 'Oude Doelenstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012ED',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Oude Doelenstraat 1, 1012ED, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37182, 'lon': 4.89623},
#    'viewport': {'topLeftPoint': {'lat': 52.37272, 'lon': 4.89476},
#     'btmRightPoint': {'lat': 52.37092, 'lon': 4.8977}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37175, 'lon': 4.89617}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/379856',
#    'score': 5.14825,
#    'dist': 1116.2325643027473,
#    'info': 'search:ta:528001000024710-NL',
#    'poi': {'name': 'Oriental City',
#     'phone': '+(31)-(20)-6268352',
#     'categorySet': [{'id': 7315012}],
#     'url': 'oriental-city.com',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '177-179',
#     'streetName': 'Oudezijds Voorburgwal',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1012',
#     'extendedPostalCode': '1012EV',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Oudezijds Voorburgwal 177-179, 1012EV, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.37184, 'lon': 4.89619},
#    'viewport': {'topLeftPoint': {'lat': 52.37274, 'lon': 4.89472},
#     'btmRightPoint': {'lat': 52.37094, 'lon': 4.89766}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.37187, 'lon': 4.89613}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/733711',
#    'score': 5.14823,
#    'dist': 1131.7809423867554,
#    'info': 'search:ta:528009005861336-NL',
#    'poi': {'name': "Panda's Kitchen",
#     'phone': '+(31)-(20)-7372236',
#     'categorySet': [{'id': 7315012}],
#     'url': 'pandaskitchen.nl/',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '30',
#     'streetName': 'Haarlemmerdijk',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1013',
#     'extendedPostalCode': '1013JC',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Haarlemmerdijk 30, 1013JC, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.38205, 'lon': 4.88841},
#    'viewport': {'topLeftPoint': {'lat': 52.38295, 'lon': 4.88694},
#     'btmRightPoint': {'lat': 52.38115, 'lon': 4.88988}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.38202, 'lon': 4.88836}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/730704',
#    'score': 5.1482,
#    'dist': 1152.5573355574127,
#    'info': 'search:ta:528009007985312-NL',
#    'poi': {'name': "Mr Tong's",
#     'phone': '+(31)-(20)-6234829',
#     'categorySet': [{'id': 7315012}],
#     'url': 'mrtongs.eu',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '119-121',
#     'streetName': 'Korte Leidsedwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017PZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Korte Leidsedwarsstraat 119-121, 1017PZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36333, 'lon': 4.88462},
#    'viewport': {'topLeftPoint': {'lat': 52.36423, 'lon': 4.88315},
#     'btmRightPoint': {'lat': 52.36243, 'lon': 4.88609}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36329, 'lon': 4.88466}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/334858',
#    'score': 5.14819,
#    'dist': 1160.0918727202363,
#    'info': 'search:ta:528009005858835-NL',
#    'poi': {'name': 'Mr Tongs',
#     'phone': '+(31)-(20)-6234829',
#     'categorySet': [{'id': 7315012}],
#     'url': 'mrtongs.eu',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '119',
#     'streetName': 'Korte Leidsedwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017PZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Korte Leidsedwarsstraat 119, 1017PZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36331, 'lon': 4.8849},
#    'viewport': {'topLeftPoint': {'lat': 52.36421, 'lon': 4.88343},
#     'btmRightPoint': {'lat': 52.36241, 'lon': 4.88637}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36323, 'lon': 4.88475}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/109857',
#    'score': 5.14815,
#    'dist': 1185.139792854858,
#    'info': 'search:ta:528009005857203-NL',
#    'poi': {'name': 'Taste Of Culture',
#     'phone': '+(31)-(20)-4271136',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.tasteofculture.net',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '139HS',
#     'streetName': 'Korte Leidsedwarsstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017PZ',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Korte Leidsedwarsstraat 139HS, 1017PZ, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36311, 'lon': 4.88509},
#    'viewport': {'topLeftPoint': {'lat': 52.36401, 'lon': 4.88362},
#     'btmRightPoint': {'lat': 52.36221, 'lon': 4.88656}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36305, 'lon': 4.885}}]},
#   {'type': 'POI',
#    'id': 'NL/POI/p0/113380',
#    'score': 5.14815,
#    'dist': 1186.9224397671223,
#    'info': 'search:ta:528009008027878-NL',
#    'poi': {'name': 'Asian Kitchen',
#     'phone': '+(31)-(20)-6201816',
#     'categorySet': [{'id': 7315012}],
#     'url': 'www.asiankitchen.nl',
#     'categories': ['chinese', 'restaurant'],
#     'classifications': [{'code': 'RESTAURANT',
#       'names': [{'nameLocale': 'en-US', 'name': 'chinese'},
#        {'nameLocale': 'en-US', 'name': 'restaurant'}]}]},
#    'address': {'streetNumber': '5A',
#     'streetName': 'Vijzelstraat',
#     'municipalitySubdivision': 'Amsterdam',
#     'municipality': 'Amsterdam',
#     'countrySubdivision': 'North Holland',
#     'postalCode': '1017',
#     'extendedPostalCode': '1017HD',
#     'countryCode': 'NL',
#     'country': 'Netherlands',
#     'countryCodeISO3': 'NLD',
#     'freeformAddress': 'Vijzelstraat 5A, 1017HD, Amsterdam',
#     'localName': 'Amsterdam'},
#    'position': {'lat': 52.36656, 'lon': 4.89349},
#    'viewport': {'topLeftPoint': {'lat': 52.36746, 'lon': 4.89202},
#     'btmRightPoint': {'lat': 52.36566, 'lon': 4.89496}},
#    'entryPoints': [{'type': 'main',
#      'position': {'lat': 52.36657, 'lon': 4.89331}}]}]}

# %%
# add a grey circle to represent the search radius
folium.Circle(
    [lat_area, lon_area],
    radius=1200,
    color='#004B7F', # Navy
    opacity=0.3,
    fill = False
).add_to(TomTom_map)

# Add POIs one by one to the map
for poi in result['results']:
    folium.Marker(location=tuple(poi['position'].values()),
                  popup=str(poi['poi']['name']), 
                  icon=folium.Icon(color='blue', icon='glyphicon-star')
                  #icon=icon
             ).add_to(TomTom_map)
TomTom_map.save('Area_POI.html')
TomTom_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Legends of the above map
#
# 1. **Blue markers**: Chinese restaurants.
# 2. **Blue area**: The shape of the neighborhood
# 3. **Grey circle**: the search radius.
#
# ### Learnings of the map above
#
# 1. According to Foursquare there are 10 Chinese Restaurants within the range of 500 meters in the neighborhood Oude Pijp.
# 2. As to Asian restaurants. Due to the 45 limit, we can only show 45 Asian restaurants here. The actual number could be higher.
# 3. From the map we learn that in the North and Southeast of Oude Pijp seems to be a void of all restaurants. If we  open a Chinese restaurant there, we will likely have enough customers.
#
# <a id="433"></a>
#
# ### 4.3.3. Repeat the In-depth Analysis
#
# We can see the value of the in-depth analysis. Later on, we will repeat this analysis to all other remaining candidate neighborhoods. We will compare more categories of venues. Such as, Chinese restaurants and all other restaurants, café, snack bars, etc.
#
# <br>
# <hr style="border: 1px solid orange;">

# %% [markdown]
# # 5. Conclusion and Future Work<a id='5'></a>
# [Back to top](#top)
#
# ## The limitation of this project
#
# #### Only focus on residential information
#
# This project is limited by the lack of crucial information. So far we have been focused quite a lot on residences information and one-person households. However, customers can also come from nearby business venues. We are unable to validate any assumption or answer any questions, because the information of business venues in Amsterdam is not as available as demographic information.
#
# #### Rent of a venue is not taken into consideration
#
# Due to lack of information, we are unable to include rental price as part of the analysis. The rent is a large part of costs for a restaurant. In order to be able to predict the potential profit, it is crucial to include potential rental price.
#
# #### Explore more POI categories
#
# There are other facilities in the neighborhood may influence the income of the restaurant. For instance:
#
# * **How easy it is to reach the place via public transportation?**<br>
# Search for nearby bus stops, tram stations, train stations, etc.
# * **How easy it is to park your car in the neighborhood?**<br>
# Search for nearby parking garages or open parking places.
#
#
# ## Next Step
#
# * Continue to perform the same in-depth analysis to all neighborhoods as we did in [5. In-depth analysis of one neighborhood](#5).
# * Include rental price of each neighborhood in future analysis.
#
# <div class="" style="margin-top: 200px">
# </div>
